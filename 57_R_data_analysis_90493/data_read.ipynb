# %%
import pandas as pd

# %%
df = pd.read_csv("dataset1.csv")

# %%
df.head()
# Out:
#        Date  Attendance  Admissions  Tri_1  Tri_2  Tri_3  Tri_4  Tri_5  \
# 0  1-Jul-13         235          99    8.0     33     89     85   20.0
# 1  2-Jul-13         209          97    NaN     41     73     80   14.0
# 2  3-Jul-13         204          84    7.0     40     72     79    6.0
# 3  4-Jul-13         199         106    3.0     37     73     70   15.0
# 4  5-Jul-13         193          96    4.0     40     76     62   11.0
#
#    Attendance.1  Admissions.1  Tri_1.1  Tri_2.1  Tri_3.1  Tri_4.1  Tri_5.1  \
# 0           155            70      NaN       25       67       54        9
# 1           145            56      NaN       22       51       47       24
# 2           118            60      NaN       24       37       43       12
# 3           125            61      NaN       21       47       42       14
# 4           136            58      4.0       23       51       45       13
#
#    Attendance.2  Admissions.2  Tri_1.2  Tri_2.2  Tri_3.2  Tri_4.2  Tri_5.2  \
# ...

# %%
rows = len(df.axes[0])
cols = len(df.axes[1])
print(df.axes[1])
# Out:
# Index(['Date', 'Attendance', 'Admissions', 'Tri_1', 'Tri_2', 'Tri_3', 'Tri_4',
#        'Tri_5', 'Attendance.1', 'Admissions.1', 'Tri_1.1', 'Tri_2.1',
#        'Tri_3.1', 'Tri_4.1', 'Tri_5.1', 'Attendance.2', 'Admissions.2',
#        'Tri_1.2', 'Tri_2.2', 'Tri_3.2', 'Tri_4.2', 'Tri_5.2', 'Attendance.3',
#        'Admissions.3', 'Tri_1.3', 'Tri_2.3', 'Tri_3.3', 'Tri_4.3', 'Tri_5.3',
#        'Attendance.4', 'Admissions.4', 'Tri_1.4', 'Tri_2.4', 'Tri_3.4',
#        'Tri_4.4', 'Tri_5.4', 'Attendance.5', 'Admissions.5', 'Tri_1.5',
#        'Tri_2.5', 'Tri_3.5', 'Tri_4.5', 'Tri_5.5', 'Attendance.6',
#        'Admissions.6', 'Tri_1.6', 'Tri_2.6', 'Tri_3.6', 'Tri_4.6', 'Tri_5.6',
#        'Attendance.7', 'Admissions.7', 'Tri_1.7', 'Tri_2.7', 'Tri_3.7',
#        'Tri_4.7', 'Tri_5.7', 'Attendance.8', 'Admissions.8', 'Tri_1.8',
#        'Tri_2.8', 'Tri_3.8', 'Tri_4.8', 'Tri_5.8'],
#       dtype='object')

# %%
print("Number of Rows: " + str(rows))
print("Number of Columns: " + str(cols))
print(cols)
# Out:
# Number of Rows: 365
# Number of Columns: 64
# 64

# %%
df = pd.DataFrame(df)
print(df.dtypes)
# Out:
# Date           object
# Attendance      int64
# Admissions      int64
# Tri_1         float64
# Tri_2           int64
#                ...
# Tri_1.8       float64
# Tri_2.8         int64
# Tri_3.8         int64
# Tri_4.8         int64
# Tri_5.8        object
# Length: 64, dtype: object

# %%
df['Date']
# Out:
# 0       1-Jul-13
# 1       2-Jul-13
# 2       3-Jul-13
# 3       4-Jul-13
# 4       5-Jul-13
#          ...
# 360    26-Jun-14
# 361    27-Jun-14
# 362    28-Jun-14
# 363    29-Jun-14
# 364    30-Jun-14
# Name: Date, Length: 365, dtype: object

# %%
df['Admissions']
# Out:
# 0       99
# 1       97
# 2       84
# 3      106
# 4       96
#       ...
# 360    112
# 361    112
# 362     95
# 363     87
# 364    113
# Name: Admissions, Length: 365, dtype: int64

# %%
df['Attendance']
# Out:
# 0      235
# 1      209
# 2      204
# 3      199
# 4      193
#       ...
# 360    222
# 361    224
# 362    239
# 363    218
# 364    234
# Name: Attendance, Length: 365, dtype: int64

# %%
df['Tri_1']
# Out:
# 0       8.0
# 1       NaN
# 2       7.0
# 3       3.0
# 4       4.0
#        ...
# 360     4.0
# 361     NaN
# 362     5.0
# 363    15.0
# 364     8.0
# Name: Tri_1, Length: 365, dtype: float64
